# %% [markdown]
# ## Perintah pada python dibatasi oleh baris

# %%
print("Apa kabar dunia")
print  ("Apa kabar dunia")
print('Apa kabar dunia')
# Out:
# Apa kabar dunia
# Apa kabar dunia
# Apa kabar dunia

# %%
print("Apa kabar dunia"); print("Apa kabar dunia")
print('Apa kabar dunia')
# Out:
# Apa kabar dunia
# Apa kabar dunia
# Apa kabar dunia

# %%
print("""
baris ke satu
baris ke dua
 baris ke tiga
   baris ke empat""")
# Out:
# baris ke satu
# baris ke dua
#  baris ke tiga
#    baris ke empat

# %% [markdown]
# ## Komentar

# %%
# ini komentar

# %%
print('ini bukan komentar') #ini komentar
# Out:
# ini bukan komentar

# %% [markdown]
# ## Case sensitive

# %%
Print("a")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b33d3f360c16> in <module>
# ----> 1 Print("a")
#
# NameError: name 'Print' is not defined

# %% [markdown]
# ## Deklarasi variable

# %%
x = 3
print(type(x)) # Prints "<class 'int'>"
print(x)
# Out:
# <class 'int'>
# 3

# %%
x = "tiga"

# %%
print(type(x)) # Prints "<class 'int'>"
print(x)
# Out:
# <class 'str'>
# tiga

# %%
print(type(y))
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-31fe00d90159> in <module>
# ----> 1 print(type(y))
#       2 print(y)
#
# NameError: name 'y' is not defined

# %% [markdown]
# ## Sensitif terhadap indent

# %%
x = 3
 x = 4
# Out:
#   File "<ipython-input-11-583b0f68f855>", line 2
#     x = 4
#     ^
# IndentationError: unexpected indent

# %%
for x in [1, 2, 3]:
    print(x)
    print("-")
# Out:
# 1
# -
# 2
# -
# 3
# -

# %%
for x in [1, 2, 3]:
    print(x)
print("-")
# Out:
# 1
# 2
# 3
# -

# %% [markdown]
# ## Kondisional/Percabangan

# %%
x = 6
if x == 0:
    print(x, ': nol')
elif x == 1:
    print(x, ': satu')
elif x > 1 and x <= 5:
    print('antara 2 dan 5')
else:
    print('lebih besar dari 5')
print(x)
# Out:
# lebih besar dari 5
# 6

# %% [markdown]
# ## Perulangan

# %%
for x in [1, 2, 3]:
    print(x)
# Out:
# 1
# 2
# 3

# %%
for x in range(1, 6, 2):
    print(x)
# Out:
# 1
# 3
# 5

# %%
x = 1
while x < 5:
    print(x)
    x = x + 1
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Fungsi

# %%
def ubah_ke_text(x):
    hasil = "tidak ada"
    if x == 0:
        hasil = "nol"
    elif x == 1:
        hasil = "satu"
    elif x == 2:
        hasil = "dua"
    return hasil

# %%
x = 2
y = ubah_ke_text(x)
print(y)
# Out:
# dua

# %%
def fungsi_lain(x, y):
    hasil1 = "tidak ada"
    hasil2 = x + y
    if x == 0:
        hasil1 = "nol"
    elif x == 1:
        hasil1 = "satu"
    elif x == 2:
        hasil1 = "dua"
    return hasil1, hasil2

# %%
x = 2
res1, res2 = fungsi_lain(x, 2)
print(res1)
print(res2)
# Out:
# dua
# 4

# %% [markdown]
# ## Menggunakan Paket Library

# %%
# Python version
import sys
print('Python: {}'.format(sys.version))
# Out:
# Python: 3.7.7 (default, May  6 2020, 11:45:54) [MSC v.1916 64 bit (AMD64)]

# %%
import numpy
print('numpy: {}'.format(numpy.__version__))
# Out:
# numpy: 1.18.1

# %%
import pandas as pd
print('pandas: {}'.format(pd.__version__))
# Out:
# pandas: 1.0.3

# %%
df = pd.DataFrame({'col1': [4, 5, 6, 7],
                   'col2': [10, 20, 30, 40],
                   'col3': [100, 50, -30, -50]})
df
# Out:
#    col1  col2  col3
# 0     4    10   100
# 1     5    20    50
# 2     6    30   -30
# 3     7    40   -50
